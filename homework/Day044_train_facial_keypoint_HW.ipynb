# %% [markdown]
# ### 作業
# 請嘗試使用 flip (左右翻轉) 來做 augmentation 以降低人臉關鍵點檢測的 loss
#
# Note: 圖像 flip 之後，groundtruth 的關鍵點也要跟著 flip 哦

# %% [markdown]
# ### 範例
# 接下來的程式碼會示範如何定義一個簡單的 CNN model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 使用 colab 環境的同學請執行以下程式碼
# %tensorflow_version 1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2
# import tensorflow as tf
# print(tf.__version__)

# import os
# from google.colab import drive 
# drive.mount('/content/gdrive') # 將 google drive 掛載在 colob，
# %cd 'gdrive/My Drive'
# os.system("mkdir cupoy_cv_part4") # 可以自己改路徑
# %cd cupoy_cv_part4 # 可以自己改路徑

# %%
# 讀取資料集以及做前處理的函數
def load_data(dirname):
    # 讀取 csv 文件
    data = pd.read_csv(dirname)
    # 過濾有缺失值的 row
    data = data.dropna()

    # 將圖片像素值讀取為 numpy array 的形態
    data['Image'] = data['Image'].apply(lambda img: np.fromstring(img, sep=' ')).values 

    # 單獨把圖像 array 抽取出來
    imgs = np.vstack(data['Image'].values)/255
    # reshape 為 96 x 96
    imgs = imgs.reshape(data.shape[0], 96, 96)
    # 轉換為 float
    imgs = imgs.astype(np.float32)
    
    # 提取坐標的部分
    points = data[data.columns[:-1]].values

    # 轉換為 float
    points = points.astype(np.float32)

    # normalize 坐標值到 [-0.5, 0.5]
    points = points/96 - 0.5
    
    return imgs, points

# %%
# 讀取資料
imgs_train, points_train = load_data(dirname = 'training.csv')
print("圖像資料:", imgs_train.shape, "\n關鍵點資料:", points_train.shape)
# Out:
# 圖像資料: (2140, 96, 96)
# 關鍵點資料: (2140, 30)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
# Out:
# Using TensorFlow backend.
# C:\Users\user\Anaconda3\envs\NEW_2020_02_03\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\user\Anaconda3\envs\NEW_2020_02_03\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\user\Anaconda3\envs\NEW_2020_02_03\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\user\Anaconda3\envs\NEW_2020_02_03\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\user\Anaconda3\envs\NEW_2020_02_03\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\user\Anaconda3\envs\NEW_2020_02_03\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\Users\user\Anaconda3\envs\NEW_2020_02_03\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\user\Anaconda3\envs\NEW_2020_02_03\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\user\Anaconda3\envs\NEW_2020_02_03\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\user\Anaconda3\envs\NEW_2020_02_03\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\user\Anaconda3\envs\NEW_2020_02_03\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\user\Anaconda3\envs\NEW_2020_02_03\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
# 回傳定義好的 model 的函數
def get_model():
    # 定義人臉關鍵點檢測網路
    model = Sequential()

    # 定義神經網路的輸入
    model.add(Conv2D(filters=16, kernel_size=3, activation='relu', input_shape=(96, 96, 1)))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=32, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=64, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=128, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))

    # 最後輸出 30 維的向量，也就是 15 個關鍵點的值
    model.add(Dense(30))
    return model

# %%
model = get_model()
# 配置 loss funtion 和 optimizer
model.compile(loss='mean_squared_error', optimizer='adam')
# Out:
# WARNING:tensorflow:From C:\Users\user\Anaconda3\envs\NEW_2020_02_03\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\user\Anaconda3\envs\NEW_2020_02_03\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From C:\Users\user\Anaconda3\envs\NEW_2020_02_03\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From C:\Users\user\Anaconda3\envs\NEW_2020_02_03\lib\site-packages\keras\backend\tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From C:\Users\user\Anaconda3\envs\NEW_2020_02_03\lib\site-packages\keras\backend\tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From C:\Users\user\Anaconda3\envs\NEW_2020_02_03\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From C:\Users\user\Anaconda3\envs\NEW_2020_02_03\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
# 印出網路結構
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 94, 94, 16)        160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 47, 47, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 45, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 20, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 30)                15390
# =================================================================
# Total params: 1,424,286
# Trainable params: 1,424,286
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, History
# model checkpoint 
checkpoint = ModelCheckpoint('best_weights.h5', verbose=1, save_best_only=True)
hist = History()

# %%
# training the model
hist_model = model.fit(imgs_train.reshape(-1, 96, 96, 1), 
                       points_train, 
                       validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
                       shuffle=True, epochs=150, verbose=1)
# save the model weights
model.save_weights('weights.h5')
# save the model
model.save('model.h5')
# Out:
# WARNING:tensorflow:From C:\Users\user\Anaconda3\envs\NEW_2020_02_03\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# Train on 1712 samples, validate on 428 samples
# Epoch 1/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 0.0058 - val_loss: 0.0021
#
# Epoch 00001: val_loss improved from inf to 0.00210, saving model to best_weights.h5
# Epoch 2/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 0.0016 - val_loss: 0.0020
#
# Epoch 00002: val_loss improved from 0.00210 to 0.00198, saving model to best_weights.h5
# Epoch 3/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 0.0013 - val_loss: 0.0019
#
# Epoch 00003: val_loss improved from 0.00198 to 0.00191, saving model to best_weights.h5
# Epoch 4/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 0.0011 - val_loss: 0.0019
#
# Epoch 00004: val_loss improved from 0.00191 to 0.00188, saving model to best_weights.h5
# Epoch 5/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 0.0010 - val_loss: 0.0018
#
# Epoch 00005: val_loss improved from 0.00188 to 0.00176, saving model to best_weights.h5
# Epoch 6/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 9.2983e-04 - val_loss: 0.0017
#
# Epoch 00006: val_loss improved from 0.00176 to 0.00168, saving model to best_weights.h5
# Epoch 7/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 7.6653e-04 - val_loss: 0.0015
#
# Epoch 00007: val_loss improved from 0.00168 to 0.00148, saving model to best_weights.h5
# Epoch 8/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 6.6069e-04 - val_loss: 0.0013
#
# Epoch 00008: val_loss improved from 0.00148 to 0.00132, saving model to best_weights.h5
# Epoch 9/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 5.9423e-04 - val_loss: 0.0012
#
# Epoch 00009: val_loss improved from 0.00132 to 0.00122, saving model to best_weights.h5
# Epoch 10/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 5.2946e-04 - val_loss: 0.0011
#
# Epoch 00010: val_loss improved from 0.00122 to 0.00112, saving model to best_weights.h5
# Epoch 11/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 4.9323e-04 - val_loss: 0.0011
#
# Epoch 00011: val_loss improved from 0.00112 to 0.00110, saving model to best_weights.h5
# Epoch 12/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 4.5436e-04 - val_loss: 0.0010
#
# Epoch 00012: val_loss improved from 0.00110 to 0.00101, saving model to best_weights.h5
# Epoch 13/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 4.1649e-04 - val_loss: 9.6884e-04
#
# Epoch 00013: val_loss improved from 0.00101 to 0.00097, saving model to best_weights.h5
# Epoch 14/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 3.8903e-04 - val_loss: 9.5126e-04
#
# Epoch 00014: val_loss improved from 0.00097 to 0.00095, saving model to best_weights.h5
# Epoch 15/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 3.9023e-04 - val_loss: 9.3667e-04
#
# Epoch 00015: val_loss improved from 0.00095 to 0.00094, saving model to best_weights.h5
# Epoch 16/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 3.6303e-04 - val_loss: 9.0507e-04
#
# Epoch 00016: val_loss improved from 0.00094 to 0.00091, saving model to best_weights.h5
# Epoch 17/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 3.4366e-04 - val_loss: 8.9993e-04
#
# Epoch 00017: val_loss improved from 0.00091 to 0.00090, saving model to best_weights.h5
# Epoch 18/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 3.2969e-04 - val_loss: 8.7823e-04
#
# Epoch 00018: val_loss improved from 0.00090 to 0.00088, saving model to best_weights.h5
# Epoch 19/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 3.3180e-04 - val_loss: 9.0019e-04
#
# Epoch 00019: val_loss did not improve from 0.00088
# Epoch 20/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 3.1185e-04 - val_loss: 8.5323e-04
#
# Epoch 00020: val_loss improved from 0.00088 to 0.00085, saving model to best_weights.h5
# Epoch 21/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.9941e-04 - val_loss: 8.6720e-04
#
# Epoch 00021: val_loss did not improve from 0.00085
# Epoch 22/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.8673e-04 - val_loss: 8.4655e-04
#
# Epoch 00022: val_loss improved from 0.00085 to 0.00085, saving model to best_weights.h5
# Epoch 23/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.8318e-04 - val_loss: 8.5230e-04
#
# Epoch 00023: val_loss did not improve from 0.00085
# Epoch 24/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.7206e-04 - val_loss: 8.1737e-04
#
# Epoch 00024: val_loss improved from 0.00085 to 0.00082, saving model to best_weights.h5
# Epoch 25/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.6529e-04 - val_loss: 8.0922e-04
#
# Epoch 00025: val_loss improved from 0.00082 to 0.00081, saving model to best_weights.h5
# Epoch 26/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.5268e-04 - val_loss: 8.3151e-04
#
# Epoch 00026: val_loss did not improve from 0.00081
# Epoch 27/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.4971e-04 - val_loss: 7.9318e-04
#
# Epoch 00027: val_loss improved from 0.00081 to 0.00079, saving model to best_weights.h5
# Epoch 28/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.3891e-04 - val_loss: 8.0717e-04
#
# Epoch 00028: val_loss did not improve from 0.00079
# Epoch 29/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.3963e-04 - val_loss: 8.0298e-04
#
# Epoch 00029: val_loss did not improve from 0.00079
# Epoch 30/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.4082e-04 - val_loss: 7.8360e-04
#
# Epoch 00030: val_loss improved from 0.00079 to 0.00078, saving model to best_weights.h5
# Epoch 31/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.3627e-04 - val_loss: 7.8252e-04
#
# Epoch 00031: val_loss improved from 0.00078 to 0.00078, saving model to best_weights.h5
# Epoch 32/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.2151e-04 - val_loss: 7.9980e-04
#
# Epoch 00032: val_loss did not improve from 0.00078
# Epoch 33/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.2493e-04 - val_loss: 7.9234e-04
#
# Epoch 00033: val_loss did not improve from 0.00078
# Epoch 34/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.1826e-04 - val_loss: 7.5959e-04
#
# Epoch 00034: val_loss improved from 0.00078 to 0.00076, saving model to best_weights.h5
# Epoch 35/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.1399e-04 - val_loss: 7.8140e-04
#
# Epoch 00035: val_loss did not improve from 0.00076
# Epoch 36/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.1515e-04 - val_loss: 7.8917e-04
#
# Epoch 00036: val_loss did not improve from 0.00076
# Epoch 37/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.0277e-04 - val_loss: 7.6713e-04
#
# Epoch 00037: val_loss did not improve from 0.00076
# Epoch 38/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.0520e-04 - val_loss: 7.6714e-04
#
# Epoch 00038: val_loss did not improve from 0.00076
# Epoch 39/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.9610e-04 - val_loss: 7.5550e-04
#
# Epoch 00039: val_loss improved from 0.00076 to 0.00076, saving model to best_weights.h5
# Epoch 40/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 2.0010e-04 - val_loss: 7.4750e-04
#
# Epoch 00040: val_loss improved from 0.00076 to 0.00075, saving model to best_weights.h5
# Epoch 41/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.9573e-04 - val_loss: 7.9813e-04
#
# Epoch 00041: val_loss did not improve from 0.00075
# Epoch 42/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.8274e-04 - val_loss: 7.4403e-04
#
# Epoch 00042: val_loss improved from 0.00075 to 0.00074, saving model to best_weights.h5
# Epoch 43/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.8673e-04 - val_loss: 7.7127e-04
#
# Epoch 00043: val_loss did not improve from 0.00074
# Epoch 44/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.8578e-04 - val_loss: 7.5063e-04
#
# Epoch 00044: val_loss did not improve from 0.00074
# Epoch 45/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.8705e-04 - val_loss: 7.7146e-04
#
# Epoch 00045: val_loss did not improve from 0.00074
# Epoch 46/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.8567e-04 - val_loss: 8.0058e-04
#
# Epoch 00046: val_loss did not improve from 0.00074
# Epoch 47/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.7798e-04 - val_loss: 7.5412e-04
#
# Epoch 00047: val_loss did not improve from 0.00074
# Epoch 48/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.7710e-04 - val_loss: 7.4907e-04
#
# Epoch 00048: val_loss did not improve from 0.00074
# Epoch 49/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.7270e-04 - val_loss: 7.7709e-04
#
# Epoch 00049: val_loss did not improve from 0.00074
# Epoch 50/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.7324e-04 - val_loss: 7.9844e-04
#
# Epoch 00050: val_loss did not improve from 0.00074
# Epoch 51/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.7680e-04 - val_loss: 7.8475e-04
#
# Epoch 00051: val_loss did not improve from 0.00074
# Epoch 52/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.7397e-04 - val_loss: 7.5030e-04
#
# Epoch 00052: val_loss did not improve from 0.00074
# Epoch 53/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.6489e-04 - val_loss: 7.6328e-04
#
# Epoch 00053: val_loss did not improve from 0.00074
# Epoch 54/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.6534e-04 - val_loss: 7.8646e-04
#
# Epoch 00054: val_loss did not improve from 0.00074
# Epoch 55/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.5760e-04 - val_loss: 7.6465e-04
#
# Epoch 00055: val_loss did not improve from 0.00074
# Epoch 56/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.5783e-04 - val_loss: 7.7235e-04
#
# Epoch 00056: val_loss did not improve from 0.00074
# Epoch 57/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.6022e-04 - val_loss: 7.7662e-04
#
# Epoch 00057: val_loss did not improve from 0.00074
# Epoch 58/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.5982e-04 - val_loss: 8.2236e-04
#
# Epoch 00058: val_loss did not improve from 0.00074
# Epoch 59/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.6134e-04 - val_loss: 7.4832e-04
#
# Epoch 00059: val_loss did not improve from 0.00074
# Epoch 60/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.5335e-04 - val_loss: 7.7244e-04
#
# Epoch 00060: val_loss did not improve from 0.00074
# Epoch 61/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.4810e-04 - val_loss: 7.6653e-04
#
# Epoch 00061: val_loss did not improve from 0.00074
# Epoch 62/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.5239e-04 - val_loss: 7.9458e-04
#
# Epoch 00062: val_loss did not improve from 0.00074
# Epoch 63/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.5136e-04 - val_loss: 8.1336e-04
#
# Epoch 00063: val_loss did not improve from 0.00074
# Epoch 64/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.4450e-04 - val_loss: 7.6252e-04
#
# Epoch 00064: val_loss did not improve from 0.00074
# Epoch 65/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.4356e-04 - val_loss: 7.8050e-04
#
# Epoch 00065: val_loss did not improve from 0.00074
# Epoch 66/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.4313e-04 - val_loss: 7.5839e-04
#
# Epoch 00066: val_loss did not improve from 0.00074
# Epoch 67/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.4112e-04 - val_loss: 7.5714e-04
#
# Epoch 00067: val_loss did not improve from 0.00074
# Epoch 68/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.3618e-04 - val_loss: 7.5719e-04
#
# Epoch 00068: val_loss did not improve from 0.00074
# Epoch 69/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.3922e-04 - val_loss: 7.4757e-04
#
# Epoch 00069: val_loss did not improve from 0.00074
# Epoch 70/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.4393e-04 - val_loss: 7.3452e-04
#
# Epoch 00070: val_loss improved from 0.00074 to 0.00073, saving model to best_weights.h5
# Epoch 71/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.3469e-04 - val_loss: 7.7230e-04
#
# Epoch 00071: val_loss did not improve from 0.00073
# Epoch 72/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.3652e-04 - val_loss: 7.5739e-04
#
# Epoch 00072: val_loss did not improve from 0.00073
# Epoch 73/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.3907e-04 - val_loss: 7.6801e-04
#
# Epoch 00073: val_loss did not improve from 0.00073
# Epoch 74/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.3608e-04 - val_loss: 7.9040e-04
#
# Epoch 00074: val_loss did not improve from 0.00073
# Epoch 75/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.3576e-04 - val_loss: 7.5184e-04
#
# Epoch 00075: val_loss did not improve from 0.00073
# Epoch 76/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.2915e-04 - val_loss: 7.6916e-04
#
# Epoch 00076: val_loss did not improve from 0.00073
# Epoch 77/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.2820e-04 - val_loss: 8.0144e-04
#
# Epoch 00077: val_loss did not improve from 0.00073
# Epoch 78/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.2873e-04 - val_loss: 7.4558e-04
#
# Epoch 00078: val_loss did not improve from 0.00073
# Epoch 79/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.3036e-04 - val_loss: 7.6404e-04
#
# Epoch 00079: val_loss did not improve from 0.00073
# Epoch 80/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.2347e-04 - val_loss: 7.6905e-04
#
# Epoch 00080: val_loss did not improve from 0.00073
# Epoch 81/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.2565e-04 - val_loss: 7.4282e-04
#
# Epoch 00081: val_loss did not improve from 0.00073
# Epoch 82/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.2769e-04 - val_loss: 7.4829e-04
#
# Epoch 00082: val_loss did not improve from 0.00073
# Epoch 83/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.2598e-04 - val_loss: 7.4700e-04
#
# Epoch 00083: val_loss did not improve from 0.00073
# Epoch 84/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.1992e-04 - val_loss: 7.5577e-04
#
# Epoch 00084: val_loss did not improve from 0.00073
# Epoch 85/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.1673e-04 - val_loss: 7.4100e-04
#
# Epoch 00085: val_loss did not improve from 0.00073
# Epoch 86/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.2485e-04 - val_loss: 7.4709e-04
#
# Epoch 00086: val_loss did not improve from 0.00073
# Epoch 87/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.2170e-04 - val_loss: 7.4976e-04
#
# Epoch 00087: val_loss did not improve from 0.00073
# Epoch 88/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.1802e-04 - val_loss: 7.7136e-04
#
# Epoch 00088: val_loss did not improve from 0.00073
# Epoch 89/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.1715e-04 - val_loss: 7.6957e-04
#
# Epoch 00089: val_loss did not improve from 0.00073
# Epoch 90/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.1471e-04 - val_loss: 7.6327e-04
#
# Epoch 00090: val_loss did not improve from 0.00073
# Epoch 91/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.1401e-04 - val_loss: 7.6135e-04
#
# Epoch 00091: val_loss did not improve from 0.00073
# Epoch 92/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.1280e-04 - val_loss: 7.5286e-04
#
# Epoch 00092: val_loss did not improve from 0.00073
# Epoch 93/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.1874e-04 - val_loss: 7.4684e-04
#
# Epoch 00093: val_loss did not improve from 0.00073
# Epoch 94/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.1929e-04 - val_loss: 7.8754e-04
#
# Epoch 00094: val_loss did not improve from 0.00073
# Epoch 95/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.1819e-04 - val_loss: 7.7607e-04
#
# Epoch 00095: val_loss did not improve from 0.00073
# Epoch 96/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.1729e-04 - val_loss: 7.6966e-04
#
# Epoch 00096: val_loss did not improve from 0.00073
# Epoch 97/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.1253e-04 - val_loss: 7.4127e-04
#
# Epoch 00097: val_loss did not improve from 0.00073
# Epoch 98/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.1299e-04 - val_loss: 7.8351e-04
#
# Epoch 00098: val_loss did not improve from 0.00073
# Epoch 99/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.1095e-04 - val_loss: 7.6116e-04
#
# Epoch 00099: val_loss did not improve from 0.00073
# Epoch 100/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.1254e-04 - val_loss: 7.7454e-04
#
# Epoch 00100: val_loss did not improve from 0.00073
# Epoch 101/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.0695e-04 - val_loss: 7.5291e-04
#
# Epoch 00101: val_loss did not improve from 0.00073
# Epoch 102/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.0726e-04 - val_loss: 7.6633e-04
#
# Epoch 00102: val_loss did not improve from 0.00073
# Epoch 103/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.0793e-04 - val_loss: 7.4138e-04
#
# Epoch 00103: val_loss did not improve from 0.00073
# Epoch 104/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.0732e-04 - val_loss: 7.5774e-04
#
# Epoch 00104: val_loss did not improve from 0.00073
# Epoch 105/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.0527e-04 - val_loss: 7.8340e-04
#
# Epoch 00105: val_loss did not improve from 0.00073
# Epoch 106/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.0407e-04 - val_loss: 7.9618e-04
#
# Epoch 00106: val_loss did not improve from 0.00073
# Epoch 107/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.0204e-04 - val_loss: 7.4593e-04
#
# Epoch 00107: val_loss did not improve from 0.00073
# Epoch 108/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.0278e-04 - val_loss: 7.5624e-04
#
# Epoch 00108: val_loss did not improve from 0.00073
# Epoch 109/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 9.8183e-05 - val_loss: 7.8962e-04
#
# Epoch 00109: val_loss did not improve from 0.00073
# Epoch 110/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 9.8873e-05 - val_loss: 7.8030e-04
#
# Epoch 00110: val_loss did not improve from 0.00073
# Epoch 111/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 9.9986e-05 - val_loss: 7.6654e-04
#
# Epoch 00111: val_loss did not improve from 0.00073
# Epoch 112/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.0090e-04 - val_loss: 7.9716e-04
#
# Epoch 00112: val_loss did not improve from 0.00073
# Epoch 113/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 9.7765e-05 - val_loss: 7.4044e-04
#
# Epoch 00113: val_loss did not improve from 0.00073
# Epoch 114/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 1.0054e-04 - val_loss: 7.7118e-04
#
# Epoch 00114: val_loss did not improve from 0.00073
# Epoch 115/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 9.7587e-05 - val_loss: 7.6025e-04
#
# Epoch 00115: val_loss did not improve from 0.00073
# Epoch 116/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 9.7968e-05 - val_loss: 7.5178e-04
#
# Epoch 00116: val_loss did not improve from 0.00073
# Epoch 117/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 9.5752e-05 - val_loss: 7.7709e-04
#
# Epoch 00117: val_loss did not improve from 0.00073
# Epoch 118/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 9.7038e-05 - val_loss: 7.9699e-04
#
# Epoch 00118: val_loss did not improve from 0.00073
# Epoch 119/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 9.4863e-05 - val_loss: 7.9092e-04
#
# Epoch 00119: val_loss did not improve from 0.00073
# Epoch 120/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 9.5448e-05 - val_loss: 7.9283e-04
#
# Epoch 00120: val_loss did not improve from 0.00073
# Epoch 121/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 9.3534e-05 - val_loss: 7.8030e-04
#
# Epoch 00121: val_loss did not improve from 0.00073
# Epoch 122/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 9.2438e-05 - val_loss: 7.6488e-04
#
# Epoch 00122: val_loss did not improve from 0.00073
# Epoch 123/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 9.2230e-05 - val_loss: 7.9221e-04
#
# Epoch 00123: val_loss did not improve from 0.00073
# Epoch 124/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 9.3830e-05 - val_loss: 7.7051e-04
#
# Epoch 00124: val_loss did not improve from 0.00073
# Epoch 125/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 9.2790e-05 - val_loss: 7.5198e-04
#
# Epoch 00125: val_loss did not improve from 0.00073
# Epoch 126/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 9.5172e-05 - val_loss: 7.8160e-04
#
# Epoch 00126: val_loss did not improve from 0.00073
# Epoch 127/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 9.3406e-05 - val_loss: 7.8151e-04
#
# Epoch 00127: val_loss did not improve from 0.00073
# Epoch 128/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 9.0699e-05 - val_loss: 7.5965e-04
#
# Epoch 00128: val_loss did not improve from 0.00073
# Epoch 129/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 9.0026e-05 - val_loss: 7.5827e-04
#
# Epoch 00129: val_loss did not improve from 0.00073
# Epoch 130/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 9.2609e-05 - val_loss: 7.6555e-04
#
# Epoch 00130: val_loss did not improve from 0.00073
# Epoch 131/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 9.0377e-05 - val_loss: 7.7714e-04
#
# Epoch 00131: val_loss did not improve from 0.00073
# Epoch 132/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 8.6593e-05 - val_loss: 7.6370e-04
#
# Epoch 00132: val_loss did not improve from 0.00073
# Epoch 133/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 8.6809e-05 - val_loss: 7.7358e-04
#
# Epoch 00133: val_loss did not improve from 0.00073
# Epoch 134/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 8.7434e-05 - val_loss: 7.6489e-04
#
# Epoch 00134: val_loss did not improve from 0.00073
# Epoch 135/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 8.6952e-05 - val_loss: 7.8200e-04
#
# Epoch 00135: val_loss did not improve from 0.00073
# Epoch 136/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 9.0670e-05 - val_loss: 8.0608e-04
#
# Epoch 00136: val_loss did not improve from 0.00073
# Epoch 137/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 9.0964e-05 - val_loss: 7.7044e-04
#
# Epoch 00137: val_loss did not improve from 0.00073
# Epoch 138/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 8.5846e-05 - val_loss: 7.8002e-04
#
# Epoch 00138: val_loss did not improve from 0.00073
# Epoch 139/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 8.6133e-05 - val_loss: 7.7479e-04
#
# Epoch 00139: val_loss did not improve from 0.00073
# Epoch 140/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 8.5659e-05 - val_loss: 7.2969e-04
#
# Epoch 00140: val_loss improved from 0.00073 to 0.00073, saving model to best_weights.h5
# Epoch 141/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 8.5602e-05 - val_loss: 7.8946e-04
#
# Epoch 00141: val_loss did not improve from 0.00073
# Epoch 142/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 8.2924e-05 - val_loss: 7.8946e-04
# Epoch 00142: val_loss did not improve from 0.00073
# Epoch 143/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 7.9784e-05 - val_loss: 7.8861e-04
#
# Epoch 00143: val_loss did not improve from 0.00073
# Epoch 144/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 8.1837e-05 - val_loss: 7.9049e-04
#
# Epoch 00144: val_loss did not improve from 0.00073
# Epoch 145/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 8.1821e-05 - val_loss: 7.7323e-04
#
# Epoch 00145: val_loss did not improve from 0.00073
# Epoch 146/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 8.3995e-05 - val_loss: 7.9004e-04
#
# Epoch 00146: val_loss did not improve from 0.00073
# Epoch 147/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 8.2374e-05 - val_loss: 7.9117e-04
#
# Epoch 00147: val_loss did not improve from 0.00073
# Epoch 148/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 8.0838e-05 - val_loss: 7.5277e-04
#
# Epoch 00148: val_loss did not improve from 0.00073
# Epoch 149/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 7.9718e-05 - val_loss: 7.9759e-04
#
# Epoch 00149: val_loss did not improve from 0.00073
# Epoch 150/150
# 1712/1712 [==============================] - 6s 3ms/step - loss: 8.0376e-05 - val_loss: 7.6363e-04
#
# Epoch 00150: val_loss did not improve from 0.00073

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %% [markdown]
# ### 觀察 model 在 testing 上的結果

# %%
# 讀取測試資料集
imgs_test, _ = load_data(dirname = 'test.csv')

# %%
# 在灰階圖像上畫關鍵點的函數
def plot_keypoints(img, points):
    plt.imshow(img, cmap='gray')
    for i in range(0,30,2):
        plt.scatter((points[i] + 0.5)*96, (points[i+1]+0.5)*96, color='red')

# %%
fig = plt.figure(figsize=(15,15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test = model.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], np.squeeze(points_test[i]))

# %% [markdown]
# 目前為止，大致可以觀察到，直接使用簡單的模型以及訓練方式在這組數據上應該可以在訓練集和測試集上都得到一個還不錯的結果，說明這組資料其實不會很難。

# %%
model_with_augment = get_model()
model_with_augment.compile(loss='mean_squared_error', optimizer='adam')

# %%
# Your code
# 實現圖片以及關機點 label 做左右翻轉的函數
def augment_data(img, points):
    rows, cols = img.shape
    new_img = np.copy(img)
    
    # 翻轉圖片
    for i in range(96):
        for j in range(48):
            temp = img[i][j]
            new_img[i][j] = img[i][cols-j-1]
            new_img[i][cols-j-1] = temp
            
    # 翻轉關鍵點 label
    new_points = np.copy(points)
    for i in range(0,30,2):
        new_points[i] = -points[i]
    
    # 調整對稱的 label
    new_points_temp = np.copy(new_points)
    new_points[0:2] = new_points_temp[2:4]
    new_points[2:4] = new_points_temp[0:2]
    new_points[4:6] = new_points_temp[8:10]
    new_points[6:8] = new_points_temp[10:12]
    new_points[8:10] = new_points_temp[4:6]
    new_points[10:12] = new_points_temp[6:8]
    new_points[12:14] = new_points_temp[16:18]
    new_points[14:16] = new_points_temp[18:20]
    new_points[16:18] = new_points_temp[12:14]
    new_points[18:20] = new_points_temp[14:16]
    new_points[22:24] = new_points_temp[24:26]
    new_points[24:26] = new_points_temp[22:24]
        
    return new_img, new_points

# %%
flip_img, flip_points = augment_data(imgs_train[0], points_train[0])

fig = plt.figure()
ax = fig.add_subplot(1, 2, 1, xticks=[], yticks=[])
plot_keypoints(imgs_train[0], points_train[0]) # 原來的圖片
ax = fig.add_subplot(1, 2, 2, xticks=[], yticks=[])
plot_keypoints(flip_img, flip_points) # 翻轉後的圖片

# %%
# 創建 list
aug_imgs_train = []
aug_points_train = []

# 對所有原始資料做 augmentation
for i in range(imgs_train.shape[0]):
    # 做左右翻轉
    aug_img, aug_point = augment_data(imgs_train[i], points_train[i])
    
    # append 原始資料
    aug_imgs_train.append(imgs_train[i])
    aug_points_train.append(points_train[i]) 
    
    # append 做過 augmentation 後的資料
    aug_imgs_train.append(aug_img)
    aug_points_train.append(aug_point) 

# convert to numpy
aug_imgs_train = np.array(aug_imgs_train)   
aug_points_train = np.copy(aug_points_train)

print(aug_imgs_train.shape)
print(aug_points_train.shape)
# Out:
# (4280, 96, 96)
# (4280, 30)

# %%
# model checkpoint 
checkpoint_aug = ModelCheckpoint('best_weights_augment.h5', verbose=1, save_best_only=True)
# training the model
hist_model_aug = model_with_augment.fit(aug_imgs_train.reshape(aug_imgs_train.shape[0], 96, 96, 1), aug_points_train, 
                           validation_split=0.2, batch_size=64, callbacks=[checkpoint_aug, hist],
                           shuffle=True, epochs=150, verbose=1)
# Out:
# Train on 3424 samples, validate on 856 samples
# Epoch 1/150
# 3424/3424 [==============================] - 12s 4ms/step - loss: 0.0034 - val_loss: 0.0019
#
# Epoch 00001: val_loss improved from inf to 0.00194, saving model to best_weights_augment.h5
# Epoch 2/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 0.0012 - val_loss: 0.0018
#
# Epoch 00002: val_loss improved from 0.00194 to 0.00184, saving model to best_weights_augment.h5
# Epoch 3/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 0.0010 - val_loss: 0.0018
#
# Epoch 00003: val_loss improved from 0.00184 to 0.00176, saving model to best_weights_augment.h5
# Epoch 4/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 8.6648e-04 - val_loss: 0.0016
#
# Epoch 00004: val_loss improved from 0.00176 to 0.00160, saving model to best_weights_augment.h5
# Epoch 5/150
# 3424/3424 [==============================] - 12s 3ms/step - loss: 6.4847e-04 - val_loss: 0.0011
#
# Epoch 00005: val_loss improved from 0.00160 to 0.00113, saving model to best_weights_augment.h5
# Epoch 6/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 5.3090e-04 - val_loss: 0.0010
#
# Epoch 00006: val_loss improved from 0.00113 to 0.00102, saving model to best_weights_augment.h5
# Epoch 7/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 4.6459e-04 - val_loss: 9.5925e-04
#
# Epoch 00007: val_loss improved from 0.00102 to 0.00096, saving model to best_weights_augment.h5
# Epoch 8/150
# 3424/3424 [==============================] - 12s 3ms/step - loss: 4.2034e-04 - val_loss: 9.1479e-04
#
# Epoch 00008: val_loss improved from 0.00096 to 0.00091, saving model to best_weights_augment.h5
# Epoch 9/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 3.8120e-04 - val_loss: 8.5770e-04
#
# Epoch 00009: val_loss improved from 0.00091 to 0.00086, saving model to best_weights_augment.h5
# Epoch 10/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 3.6372e-04 - val_loss: 8.0545e-04
#
# Epoch 00010: val_loss improved from 0.00086 to 0.00081, saving model to best_weights_augment.h5
# Epoch 11/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 3.3435e-04 - val_loss: 7.8108e-04
#
# Epoch 00011: val_loss improved from 0.00081 to 0.00078, saving model to best_weights_augment.h5
# Epoch 12/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 3.1611e-04 - val_loss: 7.7456e-04
#
# Epoch 00012: val_loss improved from 0.00078 to 0.00077, saving model to best_weights_augment.h5
# Epoch 13/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 3.0123e-04 - val_loss: 7.4542e-04
#
# Epoch 00013: val_loss improved from 0.00077 to 0.00075, saving model to best_weights_augment.h5
# Epoch 14/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 2.9056e-04 - val_loss: 7.5846e-04
#
# Epoch 00014: val_loss did not improve from 0.00075
# Epoch 15/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 2.8227e-04 - val_loss: 7.5450e-04
#
# Epoch 00015: val_loss did not improve from 0.00075
# Epoch 16/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 2.6536e-04 - val_loss: 7.1070e-04
#
# Epoch 00016: val_loss improved from 0.00075 to 0.00071, saving model to best_weights_augment.h5
# Epoch 17/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 2.6310e-04 - val_loss: 7.0220e-04
#
# Epoch 00017: val_loss improved from 0.00071 to 0.00070, saving model to best_weights_augment.h5
# Epoch 18/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 2.5699e-04 - val_loss: 7.0737e-04
#
# Epoch 00018: val_loss did not improve from 0.00070
# Epoch 19/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 2.4487e-04 - val_loss: 6.9209e-04
#
# Epoch 00019: val_loss improved from 0.00070 to 0.00069, saving model to best_weights_augment.h5
# Epoch 20/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 2.3776e-04 - val_loss: 6.9431e-04
#
# Epoch 00020: val_loss did not improve from 0.00069
# Epoch 21/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 2.3156e-04 - val_loss: 6.6976e-04
#
# Epoch 00021: val_loss improved from 0.00069 to 0.00067, saving model to best_weights_augment.h5
# Epoch 22/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 2.2158e-04 - val_loss: 6.5195e-04
#
# Epoch 00022: val_loss improved from 0.00067 to 0.00065, saving model to best_weights_augment.h5
# Epoch 23/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 2.1524e-04 - val_loss: 6.5638e-04
#
# Epoch 00023: val_loss did not improve from 0.00065
# Epoch 24/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 2.1196e-04 - val_loss: 6.6953e-04
#
# Epoch 00024: val_loss did not improve from 0.00065
# Epoch 25/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 2.0687e-04 - val_loss: 6.6141e-04
#
# Epoch 00025: val_loss did not improve from 0.00065
# Epoch 26/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 2.0229e-04 - val_loss: 6.8018e-04
#
# Epoch 00026: val_loss did not improve from 0.00065
# Epoch 27/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.9426e-04 - val_loss: 6.6974e-04
#
# Epoch 00027: val_loss did not improve from 0.00065
# Epoch 28/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.9273e-04 - val_loss: 6.6149e-04
#
# Epoch 00028: val_loss did not improve from 0.00065
# Epoch 29/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.8869e-04 - val_loss: 6.8554e-04
#
# Epoch 00029: val_loss did not improve from 0.00065
# Epoch 30/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.8785e-04 - val_loss: 6.4752e-04
#
# Epoch 00030: val_loss improved from 0.00065 to 0.00065, saving model to best_weights_augment.h5
# Epoch 31/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.8242e-04 - val_loss: 6.5886e-04
#
# Epoch 00031: val_loss did not improve from 0.00065
# Epoch 32/150
# 3424/3424 [==============================] - 12s 3ms/step - loss: 1.8238e-04 - val_loss: 6.5459e-04
#
# Epoch 00032: val_loss did not improve from 0.00065
# Epoch 33/150
# 3424/3424 [==============================] - 13s 4ms/step - loss: 1.7462e-04 - val_loss: 6.7797e-04
#
# Epoch 00033: val_loss did not improve from 0.00065
# Epoch 34/150
# 3424/3424 [==============================] - 12s 4ms/step - loss: 1.6949e-04 - val_loss: 6.4477e-04
#
# Epoch 00034: val_loss improved from 0.00065 to 0.00064, saving model to best_weights_augment.h5
# Epoch 35/150
# 3424/3424 [==============================] - 12s 3ms/step - loss: 1.6804e-04 - val_loss: 6.4617e-04
#
# Epoch 00035: val_loss did not improve from 0.00064
# Epoch 36/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.6937e-04 - val_loss: 6.5939e-04
#
# Epoch 00036: val_loss did not improve from 0.00064
# Epoch 37/150
# 3424/3424 [==============================] - 12s 3ms/step - loss: 1.6412e-04 - val_loss: 6.4089e-04
#
# Epoch 00037: val_loss improved from 0.00064 to 0.00064, saving model to best_weights_augment.h5
# Epoch 38/150
# 3424/3424 [==============================] - 12s 3ms/step - loss: 1.5842e-04 - val_loss: 6.6116e-04
#
# Epoch 00038: val_loss did not improve from 0.00064
# Epoch 39/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.5683e-04 - val_loss: 6.5550e-04
#
# Epoch 00039: val_loss did not improve from 0.00064
# Epoch 40/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.5722e-04 - val_loss: 6.5695e-04
#
# Epoch 00040: val_loss did not improve from 0.00064
# Epoch 41/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.5287e-04 - val_loss: 6.3394e-04
#
# Epoch 00041: val_loss improved from 0.00064 to 0.00063, saving model to best_weights_augment.h5
# Epoch 42/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.4870e-04 - val_loss: 6.4637e-04
#
# Epoch 00042: val_loss did not improve from 0.00063
# Epoch 43/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.4707e-04 - val_loss: 6.3027e-04
#
# Epoch 00043: val_loss improved from 0.00063 to 0.00063, saving model to best_weights_augment.h5
# Epoch 44/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.4746e-04 - val_loss: 6.7508e-04
#
# Epoch 00044: val_loss did not improve from 0.00063
# Epoch 45/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.4351e-04 - val_loss: 6.6141e-04
#
# Epoch 00045: val_loss did not improve from 0.00063
# Epoch 46/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.4356e-04 - val_loss: 6.5349e-04
#
# Epoch 00046: val_loss did not improve from 0.00063
# Epoch 47/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.4173e-04 - val_loss: 6.2466e-04
#
# Epoch 00047: val_loss improved from 0.00063 to 0.00062, saving model to best_weights_augment.h5
# Epoch 48/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.4191e-04 - val_loss: 6.6079e-04
#
# Epoch 00048: val_loss did not improve from 0.00062
# Epoch 49/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.3813e-04 - val_loss: 6.4374e-04
#
# Epoch 00049: val_loss did not improve from 0.00062
# Epoch 50/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.3538e-04 - val_loss: 6.6039e-04
#
# Epoch 00050: val_loss did not improve from 0.00062
# Epoch 51/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.3522e-04 - val_loss: 6.6080e-04
#
# Epoch 00051: val_loss did not improve from 0.00062
# Epoch 52/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.3339e-04 - val_loss: 6.3880e-04
#
# Epoch 00052: val_loss did not improve from 0.00062
# Epoch 53/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.3024e-04 - val_loss: 6.4007e-04
#
# Epoch 00053: val_loss did not improve from 0.00062
# Epoch 54/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.2788e-04 - val_loss: 6.1427e-04
#
# Epoch 00054: val_loss improved from 0.00062 to 0.00061, saving model to best_weights_augment.h5
# Epoch 55/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.2637e-04 - val_loss: 6.3365e-04
#
# Epoch 00055: val_loss did not improve from 0.00061
# Epoch 56/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.2874e-04 - val_loss: 6.5547e-04
#
# Epoch 00056: val_loss did not improve from 0.00061
# Epoch 57/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.2634e-04 - val_loss: 6.7386e-04
#
# Epoch 00057: val_loss did not improve from 0.00061
# Epoch 58/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.2408e-04 - val_loss: 6.2816e-04
#
# Epoch 00058: val_loss did not improve from 0.00061
# Epoch 59/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.2141e-04 - val_loss: 6.3725e-04
#
# Epoch 00059: val_loss did not improve from 0.00061
# Epoch 60/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.1848e-04 - val_loss: 6.3325e-04
#
# Epoch 00060: val_loss did not improve from 0.00061
# Epoch 61/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.1940e-04 - val_loss: 6.3418e-04
#
# Epoch 00061: val_loss did not improve from 0.00061
# Epoch 62/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.1566e-04 - val_loss: 6.3701e-04
#
# Epoch 00062: val_loss did not improve from 0.00061
# Epoch 63/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.1830e-04 - val_loss: 6.4285e-04
#
# Epoch 00063: val_loss did not improve from 0.00061
# Epoch 64/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.1598e-04 - val_loss: 6.5150e-04
#
# Epoch 00064: val_loss did not improve from 0.00061
# Epoch 65/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.1699e-04 - val_loss: 6.5997e-04
#
# Epoch 00065: val_loss did not improve from 0.00061
# Epoch 66/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.1422e-04 - val_loss: 6.5461e-04
#
# Epoch 00066: val_loss did not improve from 0.00061
# Epoch 67/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.1399e-04 - val_loss: 6.4393e-04
#
# Epoch 00067: val_loss did not improve from 0.00061
# Epoch 68/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.1253e-04 - val_loss: 6.1555e-04
#
# Epoch 00068: val_loss did not improve from 0.00061
# Epoch 69/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.0937e-04 - val_loss: 6.4078e-04
#
# Epoch 00069: val_loss did not improve from 0.00061
# Epoch 70/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.0844e-04 - val_loss: 6.3869e-04
#
# Epoch 00070: val_loss did not improve from 0.00061
# Epoch 71/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.0792e-04 - val_loss: 6.3673e-04
#
# Epoch 00071: val_loss did not improve from 0.00061
# Epoch 72/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.0983e-04 - val_loss: 6.4446e-04
#
# Epoch 00072: val_loss did not improve from 0.00061
# Epoch 73/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.0915e-04 - val_loss: 6.1054e-04
#
# Epoch 00073: val_loss improved from 0.00061 to 0.00061, saving model to best_weights_augment.h5
# Epoch 74/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.0840e-04 - val_loss: 6.2825e-04
#
# Epoch 00074: val_loss did not improve from 0.00061
# Epoch 75/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.0579e-04 - val_loss: 6.2672e-04
#
# Epoch 00075: val_loss did not improve from 0.00061
# Epoch 76/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.0565e-04 - val_loss: 6.3463e-04
#
# Epoch 00076: val_loss did not improve from 0.00061
# Epoch 77/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.0307e-04 - val_loss: 6.3901e-04
#
# Epoch 00077: val_loss did not improve from 0.00061
# Epoch 78/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.0466e-04 - val_loss: 6.1643e-04
#
# Epoch 00078: val_loss did not improve from 0.00061
# Epoch 79/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.0273e-04 - val_loss: 6.2371e-04
#
# Epoch 00079: val_loss did not improve from 0.00061
# Epoch 80/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.0082e-04 - val_loss: 6.4726e-04
#
# Epoch 00080: val_loss did not improve from 0.00061
# Epoch 81/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.0142e-04 - val_loss: 6.2574e-04
#
# Epoch 00081: val_loss did not improve from 0.00061
# Epoch 82/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 9.8551e-05 - val_loss: 6.4821e-04
#
# Epoch 00082: val_loss did not improve from 0.00061
# Epoch 83/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 9.6898e-05 - val_loss: 6.2805e-04
#
# Epoch 00083: val_loss did not improve from 0.00061
# Epoch 84/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 9.8352e-05 - val_loss: 6.4481e-04
#
# Epoch 00084: val_loss did not improve from 0.00061
# Epoch 85/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 9.9229e-05 - val_loss: 6.5327e-04
#
# Epoch 00085: val_loss did not improve from 0.00061
# Epoch 86/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 1.0188e-04 - val_loss: 6.5167e-04
#
# Epoch 00086: val_loss did not improve from 0.00061
# Epoch 87/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 9.8441e-05 - val_loss: 6.5382e-04
#
# Epoch 00087: val_loss did not improve from 0.00061
# Epoch 88/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 9.6738e-05 - val_loss: 6.6880e-04
#
# Epoch 00088: val_loss did not improve from 0.00061
# Epoch 89/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 9.7358e-05 - val_loss: 6.4136e-04
#
# Epoch 00089: val_loss did not improve from 0.00061
# Epoch 90/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 9.5250e-05 - val_loss: 6.2226e-04
#
# Epoch 00090: val_loss did not improve from 0.00061
# Epoch 91/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 9.4044e-05 - val_loss: 6.4276e-04
#
# Epoch 00091: val_loss did not improve from 0.00061
# Epoch 92/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 9.7495e-05 - val_loss: 6.5367e-04
#
# Epoch 00092: val_loss did not improve from 0.00061
# Epoch 93/150
# 3424/3424 [==============================] - 12s 3ms/step - loss: 9.1233e-05 - val_loss: 6.4840e-04
#
# Epoch 00093: val_loss did not improve from 0.00061
# Epoch 94/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 9.4507e-05 - val_loss: 6.4580e-04
#
# Epoch 00094: val_loss did not improve from 0.00061
# Epoch 95/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 9.3750e-05 - val_loss: 6.2397e-04
#
# Epoch 00095: val_loss did not improve from 0.00061
# Epoch 96/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 9.3416e-05 - val_loss: 6.6997e-04
#
# Epoch 00096: val_loss did not improve from 0.00061
# Epoch 97/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 9.3909e-05 - val_loss: 6.3015e-04
#
# Epoch 00097: val_loss did not improve from 0.00061
# Epoch 98/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 9.2382e-05 - val_loss: 6.6068e-04
#
# Epoch 00098: val_loss did not improve from 0.00061
# Epoch 99/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 8.9328e-05 - val_loss: 6.3921e-04
#
# Epoch 00099: val_loss did not improve from 0.00061
# Epoch 100/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 8.8722e-05 - val_loss: 6.3782e-04
#
# Epoch 00100: val_loss did not improve from 0.00061
# Epoch 101/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 8.8886e-05 - val_loss: 6.4629e-04
#
# Epoch 00101: val_loss did not improve from 0.00061
# Epoch 102/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 9.0977e-05 - val_loss: 6.3705e-04
#
# Epoch 00102: val_loss did not improve from 0.00061
# Epoch 103/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 9.1987e-05 - val_loss: 6.5443e-04
#
# Epoch 00103: val_loss did not improve from 0.00061
# Epoch 104/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 8.9171e-05 - val_loss: 6.3809e-04
#
# Epoch 00104: val_loss did not improve from 0.00061
# Epoch 105/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 8.8500e-05 - val_loss: 6.3389e-04
#
# Epoch 00105: val_loss did not improve from 0.00061
# Epoch 106/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 8.9328e-05 - val_loss: 6.4162e-04
#
# Epoch 00106: val_loss did not improve from 0.00061
# Epoch 107/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 8.6820e-05 - val_loss: 6.4519e-04
#
# Epoch 00107: val_loss did not improve from 0.00061
# Epoch 108/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 8.6312e-05 - val_loss: 6.1764e-04
#
# Epoch 00108: val_loss did not improve from 0.00061
# Epoch 109/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 8.6272e-05 - val_loss: 6.4014e-04
#
# Epoch 00109: val_loss did not improve from 0.00061
# Epoch 110/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 8.7322e-05 - val_loss: 6.4409e-04
#
# Epoch 00110: val_loss did not improve from 0.00061
# Epoch 111/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 8.7587e-05 - val_loss: 6.5870e-04
#
# Epoch 00111: val_loss did not improve from 0.00061
# Epoch 112/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 8.9408e-05 - val_loss: 6.4111e-04
#
# Epoch 00112: val_loss did not improve from 0.00061
# Epoch 113/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 8.4798e-05 - val_loss: 6.4045e-04
#
# Epoch 00113: val_loss did not improve from 0.00061
# Epoch 114/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 8.5312e-05 - val_loss: 6.3913e-04
#
# Epoch 00114: val_loss did not improve from 0.00061
# Epoch 115/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 8.4831e-05 - val_loss: 6.2822e-04
#
# Epoch 00115: val_loss did not improve from 0.00061
# Epoch 116/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 8.2977e-05 - val_loss: 6.3040e-04
#
# Epoch 00116: val_loss did not improve from 0.00061
# Epoch 117/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 8.3581e-05 - val_loss: 6.3702e-04
#
# Epoch 00117: val_loss did not improve from 0.00061
# Epoch 118/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 8.3120e-05 - val_loss: 6.4167e-04
#
# Epoch 00118: val_loss did not improve from 0.00061
# Epoch 119/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 8.2972e-05 - val_loss: 6.3779e-04
#
# Epoch 00119: val_loss did not improve from 0.00061
# Epoch 120/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 8.3585e-05 - val_loss: 6.3229e-04
#
# Epoch 00120: val_loss did not improve from 0.00061
# Epoch 121/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 8.3636e-05 - val_loss: 6.3776e-04
#
# Epoch 00121: val_loss did not improve from 0.00061
# Epoch 122/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 8.5841e-05 - val_loss: 6.3940e-04
#
# Epoch 00122: val_loss did not improve from 0.00061
# Epoch 123/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 8.6022e-05 - val_loss: 6.2912e-04
#
# Epoch 00123: val_loss did not improve from 0.00061
# Epoch 124/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 8.0459e-05 - val_loss: 6.4541e-04
#
# Epoch 00124: val_loss did not improve from 0.00061
# Epoch 125/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 8.1469e-05 - val_loss: 6.1650e-04
#
# Epoch 00125: val_loss did not improve from 0.00061
# Epoch 126/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 8.1551e-05 - val_loss: 6.4431e-04
#
# Epoch 00126: val_loss did not improve from 0.00061
# Epoch 127/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 8.1286e-05 - val_loss: 6.2414e-04
#
# Epoch 00127: val_loss did not improve from 0.00061
# Epoch 128/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 8.2581e-05 - val_loss: 6.4537e-04
#
# Epoch 00128: val_loss did not improve from 0.00061
# Epoch 129/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 8.4477e-05 - val_loss: 6.4003e-04
#
# Epoch 00129: val_loss did not improve from 0.00061
# Epoch 130/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 8.1604e-05 - val_loss: 6.5816e-04
#
# Epoch 00130: val_loss did not improve from 0.00061
# Epoch 131/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 8.1180e-05 - val_loss: 6.3530e-04
#
# Epoch 00131: val_loss did not improve from 0.00061
# Epoch 132/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 8.1491e-05 - val_loss: 6.4766e-04
#
# Epoch 00132: val_loss did not improve from 0.00061
# Epoch 133/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 8.1983e-05 - val_loss: 6.2302e-04
#
# Epoch 00133: val_loss did not improve from 0.00061
# Epoch 134/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 8.1884e-05 - val_loss: 6.5682e-04
#
# Epoch 00134: val_loss did not improve from 0.00061
# Epoch 135/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 8.0910e-05 - val_loss: 6.5475e-04
#
# Epoch 00135: val_loss did not improve from 0.00061
# Epoch 136/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 7.8969e-05 - val_loss: 6.2773e-04
#
# Epoch 00136: val_loss did not improve from 0.00061
# Epoch 137/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 7.7524e-05 - val_loss: 6.5837e-04
#
# Epoch 00137: val_loss did not improve from 0.00061
# Epoch 138/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 7.7358e-05 - val_loss: 6.4214e-04
#
# Epoch 00138: val_loss did not improve from 0.00061
# Epoch 139/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 7.7858e-05 - val_loss: 6.4861e-04
#
# Epoch 00139: val_loss did not improve from 0.00061
# Epoch 140/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 7.9040e-05 - val_loss: 6.3503e-04
#
# Epoch 00140: val_loss did not improve from 0.00061
# Epoch 141/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 7.7430e-05 - val_loss: 6.5647e-04
#
# Epoch 00141: val_loss did not improve from 0.00061
# Epoch 142/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 7.7545e-05 - val_loss: 6.2089e-04
#
# Epoch 00142: val_loss did not improve from 0.00061
# Epoch 143/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 7.6254e-05 - val_loss: 6.5176e-04
#
# Epoch 00143: val_loss did not improve from 0.00061
# Epoch 144/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 7.6093e-05 - val_loss: 6.3415e-04
#
# Epoch 00144: val_loss did not improve from 0.00061
# Epoch 145/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 7.7600e-05 - val_loss: 6.4366e-04
#
# Epoch 00145: val_loss did not improve from 0.00061
# Epoch 146/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 7.9042e-05 - val_loss: 6.3692e-04
#
# Epoch 00146: val_loss did not improve from 0.00061
# Epoch 147/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 7.6811e-05 - val_loss: 6.4051e-04
#
# Epoch 00147: val_loss did not improve from 0.00061
# Epoch 148/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 7.5970e-05 - val_loss: 6.4377e-04
#
# Epoch 00148: val_loss did not improve from 0.00061
# Epoch 149/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 7.5949e-05 - val_loss: 6.4566e-04
#
# Epoch 00149: val_loss did not improve from 0.00061
# Epoch 150/150
# 3424/3424 [==============================] - 11s 3ms/step - loss: 7.5539e-05 - val_loss: 6.2999e-04
#
# Epoch 00150: val_loss did not improve from 0.00061

# %%
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model_aug.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model_aug.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')
